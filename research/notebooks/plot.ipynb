# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
import seaborn as sns
import os

from scripts.config import DATA_PATH, MODELS_PATH
from scripts.plot import load_data


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
preprocess_version = 'v5'

date_from = "01/01/2021"
date_to = "31/12/2022"

df_data = load_data(preprocess_version, date_from, date_to)

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16999 entries, 46912 to 63910
# Data columns (total 49 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   datetime                   16999 non-null  datetime64[ns, Europe/Paris]
#  1   BE_Solar_forecast          16999 non-null  float64
#  2   FR_Solar_forecast          16999 non-null  float64
#  3   DE_Solar_forecast          16999 non-null  float64
#  4   IT_Solar_forecast          16999 non-null  float64
#  5   ES_Solar_forecast          16999 non-null  float64
#  6   CH_Solar_forecast          16999 non-null  float64
#  7   BE_Wind_Offshore_forecast  16999 non-null  float64
#  8   FR_Wind_Offshore_forecast  16999 non-null  float64
#  9   DE_Wind_Offshore_forecast  16999 non-null  float64
#  10  BE_Wind_Onshore_forecast   16999 non-null  float64
#  11  FR_Wind_Onshore_forecast   16999 non-null  float64
# ...

# %%
sns.lineplot(x='datetime', y='FR_price', data=df_data)
sns.lineplot(x='datetime', y='TTF_EUR', data=df_data)
# Out:
# <Axes: xlabel='datetime', ylabel='FR_price'>
